# %%
! pip install audb
# !apt-get install ffmpeg
# !pip install audioread
! pip install ripser
# Out:
# Requirement already satisfied: audb in /usr/local/lib/python3.10/dist-packages (1.11.1)
# Requirement already satisfied: audbackend>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from audbackend[all]>=2.2.1->audb) (2.2.1)
# Requirement already satisfied: audeer>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from audb) (2.2.1)
# Requirement already satisfied: audformat>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from audb) (1.3.1)
# Requirement already satisfied: audiofile>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from audb) (1.5.1)
# Requirement already satisfied: audobject>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from audb) (0.7.11)
# Requirement already satisfied: audresample>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from audb) (1.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from audb) (3.16.1)
# Requirement already satisfied: oyaml in /usr/local/lib/python3.10/dist-packages (from audb) (1.0)
# Requirement already satisfied: pandas>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from audb) (2.2.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from audb) (17.0.0)
# Requirement already satisfied: dohq-artifactory>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from audbackend[all]>=2.2.1->audb) (0.10.3)
# Requirement already satisfied: minio in /usr/local/lib/python3.10/dist-packages (from audbackend[all]>=2.2.1->audb) (7.2.14)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from audeer>=2.2.0->audb) (4.67.1)
# Requirement already satisfied: iso639-lang in /usr/local/lib/python3.10/dist-packages (from audformat>=1.2.0->audb) (2.5.1)
# Requirement already satisfied: iso3166 in /usr/local/lib/python3.10/dist-packages (from audformat>=1.2.0->audb) (2.1.1)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from audformat>=1.2.0->audb) (6.0.2)
# Requirement already satisfied: audmath>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from audiofile>=1.0.0->audb) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from audiofile>=1.0.0->audb) (1.26.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from audiofile>=1.0.0->audb) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from audobject>=0.5.0->audb) (8.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from audobject>=0.5.0->audb) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.0->audb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.0->audb) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.0->audb) (2024.2)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.10/dist-packages (from dohq-artifactory>=0.10.0->audbackend[all]>=2.2.1->audb) (2.32.3)
# Requirement already satisfied: PyJWT~=2.0 in /usr/local/lib/python3.10/dist-packages (from dohq-artifactory>=0.10.0->audbackend[all]>=2.2.1->audb) (2.10.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.8.0->audobject>=0.5.0->audb) (3.21.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1.0->audb) (1.17.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->audiofile>=1.0.0->audb) (1.17.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from minio->audbackend[all]>=2.2.1->audb) (2024.12.14)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from minio->audbackend[all]>=2.2.1->audb) (2.2.3)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from minio->audbackend[all]>=2.2.1->audb) (23.1.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.10/dist-packages (from minio->audbackend[all]>=2.2.1->audb) (3.21.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from minio->audbackend[all]>=2.2.1->audb) (4.12.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->audiofile>=1.0.0->audb) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.30.0->dohq-artifactory>=0.10.0->audbackend[all]>=2.2.1->audb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.30.0->dohq-artifactory>=0.10.0->audbackend[all]>=2.2.1->audb) (3.10)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->minio->audbackend[all]>=2.2.1->audb) (21.2.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Requirement already satisfied: audioread in /usr/local/lib/python3.10/dist-packages (3.0.1)

# %% [markdown]
# # importing necessary libraries

# %%
# Import necessary libraries
import os
import pandas as pd
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
# This allows normalization for the specgrams which allows for clearer visualizations
from matplotlib.colors import Normalize
import seaborn as sns

import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import warnings

from collections import deque

# %%
warnings.filterwarnings('ignore')
# Set style and color palette
sns.set(style='darkgrid', palette='magma')
# Change the setting and put it in a dictionary
plot_settings = {
    'font.family': 'calibri',
    'axes.titlesize': 18,
    'axes.labelsize': 14,
    'figure.dpi': 140,
    'axes.titlepad': 15,
    'axes.labelpad': 15,
    'figure.titlesize': 24,
    'figure.titleweight': 'bold',
}
# Use the dictionary variable to update the settings using matplotlib
plt.rcParams.update(plot_settings)

# %%
# Check if GPU is available
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # preparing datasets

# %%
# Put the cremad directory in a list
cremad = os.listdir('/content/drive/My Drive/content/Dataset/CREMA-D/AudioWAV/AudioMP3')

# Make a list for emotion labels and a list for path to audio files
emotions = []
paths = []
# Loop through all the files and extract the emotion label and path
for file in cremad:
    # Extract the emotion label from the file name
    emotion = file.split('_')[2]
    if emotion == 'SAD':
        emotion = 'sadness'
    elif emotion == 'ANG':
        emotion = 'anger'
    elif emotion == 'DIS':
        emotion = 'disgust'
    elif emotion == 'FEA':
        emotion = 'fear'
    elif emotion == 'HAP':
        emotion = 'happiness'
    elif emotion == 'NEU':
        emotion = 'neutral'
    elif emotion == 'SUR':
        emotion = 'surprise'
    else:
        emotion = 'Unknown'
    # Extract the path
    path = '/content/drive/My Drive/content/Dataset/CREMA-D/AudioWAV/AudioMP3' + file
    # Append the emotion and path to their lists
    emotions.append(emotion)
    paths.append(path)
# Create a dataframe from the lists
cremad_df = pd.DataFrame(emotions, columns=['Emotion'])
cremad_df['Path'] = paths
# Inspect the dataframe
cremad_df.head()
# Out:
#    Emotion                                               Path
# 0     fear  /content/drive/My Drive/content/Dataset/CREMA-...
# 1    anger  /content/drive/My Drive/content/Dataset/CREMA-...
# 2  neutral  /content/drive/My Drive/content/Dataset/CREMA-...
# 3    anger  /content/drive/My Drive/content/Dataset/CREMA-...
# 4  disgust  /content/drive/My Drive/content/Dataset/CREMA-...

# %%
# Put the ravdess directory in a list
ravdess = os.listdir('/content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/')
# Make a list for emotion labels and a list for path to audio files
emotions = []
paths = []
# Loop through all the actor directories in audio_speech_actors_01-24
for dir in ravdess:
    # Loop through all the files in each directory
    for file in os.listdir('/content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/' + dir):
        # Extract the emotion label from the file name
        emotion = file.split('-')[2]
        if emotion == '01':
            emotion = 'neutral'
        elif emotion == '02':
            emotion = 'calm'
        elif emotion == '03':
            emotion = 'happiness'
        elif emotion == '04':
            emotion = 'sadness'
        elif emotion == '05':
            emotion = 'anger'
        elif emotion == '06':
            emotion = 'fear'
        elif emotion == '07':
            emotion = 'disgust'
        elif emotion == '08':
            emotion = 'surprise'
        else:
            emotion = 'Unknown'
        # Extract the path
        path = '/content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/' + dir + '/' + file
        # Append the emotion and path to their lists
        emotions.append(emotion)
        paths.append(path)
# Create a dataframe from the lists
ravdess_df = pd.DataFrame(emotions, columns=['Emotion'])
ravdess_df['Path'] = paths
# Inspect the dataframe
ravdess_df.head()
# Out:
#      Emotion                                               Path
# 0      anger  /content/drive/My Drive/ravdess/archive/audio_...
# 1  happiness  /content/drive/My Drive/ravdess/archive/audio_...
# 2    sadness  /content/drive/My Drive/ravdess/archive/audio_...
# 3       calm  /content/drive/My Drive/ravdess/archive/audio_...
# 4    sadness  /content/drive/My Drive/ravdess/archive/audio_...

# %%
# Put the tess directory in a list
tess = os.listdir('/content/drive/My Drive/TESS/' )
# Make a list for emotion labels and a list for path to audio files
emotions = []
paths = []
# Loop through all the audio file directories
for dir in tess:
    # print(dir)
    # Loop through all the files in each directory
    for file in os.listdir('/content/drive/My Drive/TESS/' + dir):
        # Extract the emotion label from the file name
        emotion = file.split('.')[0]

        # print(len(emotion))
        try :
            emotion = emotion.split('_')[2]
        except:
            emotion=emotion.split('_')[1]

        # print(emotion)
        if emotion == 'ps':
            emotion = 'surprise'
        elif emotion == 'sad':
            emotion = 'sadness'
        elif emotion == 'disgust':
            emotion = 'disgust'
        elif emotion == 'angry':
            emotion = 'anger'
        elif emotion == 'happy':
            emotion = 'happiness'
        elif emotion == 'neutral':
            emotion = 'neutral'
        elif emotion == 'fear':
            emotion = 'fear'
        else:
            emotion = 'Unknown'
        # Extract the path
        path = '/content/drive/My Drive/TESS/' + dir + '/' + file
        # Append the emotion and path to their lists
        emotions.append(emotion)
        paths.append(path)
# Create a dataframe from the lists
tess_df = pd.DataFrame(emotions, columns=['Emotion'])
tess_df['Path'] = paths
# Inspect the dataframe
tess_df.head()
# Out:
#   Emotion                                               Path
# 0    fear  /content/drive/My Drive/TESS/YAF_fear/YAF_sour...
# 1    fear  /content/drive/My Drive/TESS/YAF_fear/YAF_sout...
# 2    fear  /content/drive/My Drive/TESS/YAF_fear/YAF_week...
# 3    fear  /content/drive/My Drive/TESS/YAF_fear/YAF_have...
# 4    fear  /content/drive/My Drive/TESS/YAF_fear/YAF_shir...

# %%
# Put the savee directory in a list
savee = os.listdir('/content/drive/My Drive/savee/')
# Make a list for emotion labels and a list for path to audio files
emotions = []
paths = []
# Loop through all the files in the ALL directory
for file in savee:

    # Separate the wav file name from the emotion label
    emotion = file.split('.')[0]
    # Extract the emotion label from the file name
    emotion = emotion.split('_')[1]
    # Exclude the numbers from the emotion label
    emotion = emotion[:-2]
    if emotion == 'a':
        emotion = 'anger'
    elif emotion == 'd':
        emotion = 'disgust'
    elif emotion == 'f':
        emotion = 'fear'
    elif emotion == 'h':
        emotion = 'happiness'
    elif emotion == 'n':
        emotion = 'neutral'
    elif emotion == 'sa':
        emotion = 'sadness'
    elif emotion == 'su':
        emotion = 'surprise'
    else:
        emotion = 'Unknown'
    # Extract the path
    path = '/content/drive/My Drive/savee/' + file
    # Append the emotion and path to their lists
    emotions.append(emotion)
    paths.append(path)
# Create a dataframe from the lists
savee_df = pd.DataFrame(emotions, columns=['Emotion'])
savee_df['Path'] = paths
# Inspect the dataframe
savee_df.head()
# Out:
#   Emotion                                      Path
# 0   anger  /content/drive/My Drive/savee/DC_a01.wav
# 1   anger  /content/drive/My Drive/savee/DC_a04.wav
# 2   anger  /content/drive/My Drive/savee/DC_a14.wav
# 3   anger  /content/drive/My Drive/savee/DC_a13.wav
# 4   anger  /content/drive/My Drive/savee/DC_a10.wav

# %%
# Plot the value counts for each emotion in each dataset
plt.figure(figsize=(14, 10))
plt.subplot(2, 2, 1)
sns.countplot(cremad_df, x = cremad_df['Emotion'], palette='magma')
plt.title('CREMA-D')
plt.xlabel('')
plt.subplot(2, 2, 2)
sns.countplot(ravdess_df, x = ravdess_df['Emotion'], palette='magma')
plt.title('RAVDESS')
plt.xlabel('')
plt.subplot(2, 2, 3)
sns.countplot(tess_df, x = tess_df['Emotion'], palette='magma')
plt.title('TESS')
plt.subplot(2, 2, 4)
sns.countplot(savee_df, x = savee_df['Emotion'], palette='magma')
plt.title('SAVEE')
plt.suptitle('Emotion Counts for Each Dataset')
# Adjust the layout so there are no overlapping titles
plt.tight_layout(pad=2)
# Remove the spines
sns.despine()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'calibri' not found.

# %%
# Count the number of emotions in each dataset
print('CREMA-D Emotion Counts:')
print(cremad_df['Emotion'].value_counts())
print('\nRAVDESS Emotion Counts:')
print(ravdess_df['Emotion'].value_counts())
print('\nTESS Emotion Counts:')
print(tess_df['Emotion'].value_counts())
print('\nSAVEE Emotion Counts:')
print(savee_df['Emotion'].value_counts())
# Out:
# CREMA-D Emotion Counts:
# Emotion
# sadness      1274
# anger        1273
# disgust      1273
# fear         1272
# happiness    1272
# neutral      1089
# Name: count, dtype: int64
#
# RAVDESS Emotion Counts:
# Emotion
# disgust      197
# fear         193
# anger        192
# happiness    192
# sadness      192
# calm         192
# surprise     192
# neutral       96
# Name: count, dtype: int64
#
# TESS Emotion Counts:
# Emotion
# disgust      402
# happiness    402
# neutral      402
# anger        402
# fear         401
# sadness      401
# surprise     400
# Unknown        6
# Name: count, dtype: int64
#
# SAVEE Emotion Counts:
# Emotion
# anger        30
# disgust      30
# neutral      30
# fear         18
# happiness    15
# surprise     15
# sadness      15
# Name: count, dtype: int64

# %%
# Create a dataframe that contains all the emotion labels and paths from all the datasets
df = pd.concat([cremad_df, ravdess_df, tess_df, savee_df], axis=0)
# Reset the index
df = df.reset_index(drop=True)
# Inspect the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11868 entries, 0 to 11867
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Emotion  11868 non-null  object
#  1   Path     11868 non-null  object
# dtypes: object(2)
# memory usage: 185.6+ KB

# %%
# Count the number of emotions in the combined dataframe
df['Emotion'].value_counts()
# Out:
# Emotion
# disgust      1902
# anger        1897
# fear         1884
# sadness      1882
# happiness    1881
# neutral      1617
# surprise      607
# calm          192
# Unknown         6
# Name: count, dtype: int64

# %%
# Drop the calm emotion as there are too few samples and it is too similar to neutral
df = df[df['Emotion'] != 'calm']
df = df[df['Emotion'] != 'Unknown']

# Check if it was dropped
df['Emotion'].value_counts()
# Out:
# Emotion
# disgust      1902
# anger        1897
# fear         1884
# sadness      1882
# happiness    1881
# neutral      1617
# surprise      607
# Name: count, dtype: int64

# %%
# Verify and filter valid file paths
df = df[df['Path'].apply(os.path.exists)]

# Sample one file for each emotion
sample = df.groupby('Emotion', group_keys=False).apply(lambda x: x.sample(1))
sample_paths = sample['Path'].tolist()

# Set font to avoid warnings
plt.rcParams['font.family'] = 'DejaVu Sans'

# Plot waveforms
plt.figure(figsize=(14, 10))
for i in range(len(sample_paths)):
    plt.subplot(4, 2, i + 1)
    data, sr = librosa.load(sample_paths[i], sr=44100)
    librosa.display.waveshow(data, sr=sr)
    plt.title(sample['Emotion'].values[i], fontweight='bold')
    plt.ylabel('Amplitude')
    plt.xlabel('Time (seconds)')

plt.tight_layout(pad=2)
plt.show()

# %%
# Encode the emotion labels into numbers
encoder = LabelEncoder()
df['Emotion'] = encoder.fit_transform(df['Emotion'])
# Make sure the encoding worked
df['Emotion'].value_counts()
# Out:
# Emotion
# 1    629
# 0    624
# 2    612
# 3    609
# 5    608
# 6    607
# 4    528
# Name: count, dtype: int64

# %%
# Create a function that extracts MFCCs from an audio file
def extract_mfcc(path):
    '''
    Load the audio file, convert the audio file into MFCCs and return the MFCCs
    '''
    # Load the audio file and set the sampling rate to 44100
    audio, sr = librosa.load(path, sr=44100, duration=4, mono=True)
    # Pad the audio files that are less than 4 seconds with zeros at the end
    if len(audio) < 4 * sr:
        audio = np.pad(audio, pad_width=(0, 4 * sr - len(audio)), mode='constant')
    # Convert the audio file into MFCC
    signal = librosa.feature.mfcc(y = audio, sr=sr, n_mfcc=128)
    # Return the MFCCs as a numpy array
    return np.array(signal)

# %%
# Test the function on the sample audio file
mfcc = extract_mfcc(sample_paths[6])
# Plot the MFCC
plt.figure(figsize=(10, 6))
librosa.display.specshow(mfcc, sr=sr, x_axis='time', cmap = 'mako', norm = Normalize( vmin = -50, vmax = 50))
plt.colorbar()
plt.title('MFCC')
# Out:
# Text(0.5, 1.0, 'MFCC')

# %%
# Visualize the MFCCs for each emotion
plt.figure(figsize=(12, 16))
for i in range(7):
    plt.subplot(4, 2, i+1)
    # Extract the MFCCs from the audio file
    mfcc = extract_mfcc(sample_paths[i])
    librosa.display.specshow(mfcc, sr=sr, x_axis='time', cmap = 'mako', norm = Normalize( vmin = -50, vmax = 50))
    plt.title(sample['Emotion'].values[i])
    plt.colorbar()
plt.tight_layout()

# %%
# # Divide the data into features and labels
# X_mfcc = [extract_mfcc(path) for path in df['Path']]
# y_mfcc = df['Emotion']


X_mfcc=[]
y_mfcc=[]

# X_mel = []
# y_mel = []
i = 0

# Iterate through the DataFrame to process each file
for index, row in df.iterrows():
    path = row['Path']  # Get the file path
    emotion = row['Emotion']  # Get the corresponding emotion
    if os.path.isfile(path):  # Ensure the path points to a valid file
        try:
            # Process the audio file and append the result to X_mel
            X_mfcc.append(extract_mfcc(path))
            # Append the corresponding emotion to y_mel
            y_mfcc.append(emotion)
            i += 1
            print(f"Processed {i}: {path}, Emotion: {emotion}")
        except Exception as e:
            print(f"Error processing {path}: {e}")

# Check the lengths of the feature and label lists
print('Number of processed audio files:', len(X_mfcc))
print('Number of labels:', len(y_mfcc))
# Out:
# Processed 1: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-05-01-02-01-24.wav, Emotion: 0
# Processed 2: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-03-02-02-01-24.wav, Emotion: 3
# Processed 3: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-04-02-01-02-24.wav, Emotion: 5
# Processed 4: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-04-02-02-01-24.wav, Emotion: 5
# Processed 5: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-05-01-02-02-24.wav, Emotion: 0
# Processed 6: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-06-01-02-01-24.wav, Emotion: 2
# Processed 7: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-06-02-02-02-24.wav, Emotion: 2
# Processed 8: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-06-02-01-01-24.wav, Emotion: 2
# Processed 9: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-04-01-02-02-24.wav, Emotion: 5
# Processed 10: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-01-01-02-02-24.wav, Emotion: 4
# Processed 11: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-06-02-02-01-24.wav, Emotion: 2
# Processed 12: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-05-01-01-01-24.wav, Emotion: 0
# Processed 13: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-07-01-01-01-24.wav, Emotion: 1
# Processed 14: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01-06-01-01-01-24.wav, Emotion: 2
# Processed 15: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_24/03-01
/content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-01-01-22.wav, Emotion: 1
# Processed 118: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-02-01-22.wav, Emotion: 3
# Processed 119: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-02-01-22.wav, Emotion: 0
# Processed 120: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-02-02-22.wav, Emotion: 5
# Processed 121: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-01-01-22.wav, Emotion: 5
# Processed 122: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-02-01-22.wav, Emotion: 0
# Processed 123: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-02-02-22.wav, Emotion: 2
# Processed 124: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-01-02-22.wav, Emotion: 0
# Processed 125: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-02-01-22.wav, Emotion: 4
# Processed 126: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-01-01-22.wav, Emotion: 4
# Processed 127: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-01-02-22.wav, Emotion: 2
# Processed 128: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-01-02-22.wav, Emotion: 1
# Processed 129: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-01-02-22.wav, Emotion: 2
# Processed 130: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-02-01-22.wav, Emotion: 2
# Processed 131: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-04-02-02-01-22.wav, Emotion: 5
# Processed 132: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-05-02-01-01-22.wav, Emotion: 0
# Processed 133: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-01-02-22.wav, Emotion: 1
# Processed 134: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-01-02-22.wav, Emotion: 3
# Processed 135: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-02-02-22.wav, Emotion: 5
# Processed 136: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-06-01-02-01-22.wav, Emotion: 2
# Processed 137: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-01-01-02-02-22.wav, Emotion: 4
# Processed 138: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-01-01-22.wav, Emotion: 1
# Processed 139: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-06-02-02-02-22.wav, Emotion: 2
# Processed 140: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-02-01-22.wav, Emotion: 3
# Processed 141: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-07-01-02-02-22.wav, Emotion: 1
# Processed 142: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-08-01-01-01-22.wav, Emotion: 6
# Processed 143: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-01-01-22.wav, Emotion: 0
# Processed 144: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-01-01-22.wav, Emotion: 3
# Processed 145: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-05-01-02-02-22.wav, Emotion: 0
# Processed 146: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-04-01-01-01-22.wav, Emotion: 5
# Processed 147: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-03-02-02-02-22.wav, Emotion: 3
# Processed 148: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-03-01-01-01-22.wav, Emotion: 3
# Processed 149: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-07-02-02-01-22.wav, Emotion: 1
# Processed 150: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-08-01-02-02-22.wav, Emotion: 6
# Processed 151: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-01-01-22.wav, Emotion: 6
# Processed 152: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-08-01-01-02-22.wav, Emotion: 6
# Processed 153: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-01-02-22.wav, Emotion: 6
# Processed 154: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-08-01-02-01-22.wav, Emotion: 6
# Processed 155: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-02-02-22.wav, Emotion: 6
# Processed 156: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_22/03-01-08-02-02-01-22.wav, Emotion: 6
# Processed 157: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-01-01-02-02-21.wav, Emotion: 4
# Processed 158: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-01-01-01-02-21.wav, Emotion: 4
# Processed 159: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-01-01-01-01-21.wav, Emotion: 4
# Processed 160: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-01-01-02-01-21.wav, Emotion: 4
# Processed 161: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-07-01-01-01-21.wav, Emotion: 1
# Processed 162: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-03-01-02-02-21.wav, Emotion: 3
# Processed 163: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-04-02-01-01-21.wav, Emotion: 5
# Processed 164: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-07-01-02-01-21.wav, Emotion: 1
# Processed 165: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-07-02-02-02-21.wav, Emotion: 1
# Processed 166: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-07-02-01-02-21.wav, Emotion: 1
# Processed 167: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-03-01-01-01-21.wav, Emotion: 3
# Processed 168: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01-05-02-01-01-21.wav, Emotion: 0
# Processed 169: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_21/03-01
/content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-03-02-01-01-15.wav, Emotion: 3
# Processed 323: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-01-01-01-02-15.wav, Emotion: 4
# Processed 324: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-05-02-01-01-15.wav, Emotion: 0
# Processed 325: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-03-01-01-02-15.wav, Emotion: 3
# Processed 326: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-04-02-01-01-15.wav, Emotion: 5
# Processed 327: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-04-01-02-02-15.wav, Emotion: 5
# Processed 328: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-03-02-02-01-15.wav, Emotion: 3
# Processed 329: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-05-01-02-02-15.wav, Emotion: 0
# Processed 330: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-01-01-02-01-15.wav, Emotion: 4
# Processed 331: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-06-01-02-01-15.wav, Emotion: 2
# Processed 332: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-05-01-01-01-15.wav, Emotion: 0
# Processed 333: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-06-02-02-01-15.wav, Emotion: 2
# Processed 334: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-04-02-02-02-15.wav, Emotion: 5
# Processed 335: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-03-01-02-01-15.wav, Emotion: 3
# Processed 336: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-04-02-02-01-15.wav, Emotion: 5
# Processed 337: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-06-01-01-01-15.wav, Emotion: 2
# Processed 338: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-04-02-01-02-15.wav, Emotion: 5
# Processed 339: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-06-01-01-02-15.wav, Emotion: 2
# Processed 340: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-03-02-01-02-15.wav, Emotion: 3
# Processed 341: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-06-01-02-02-15.wav, Emotion: 2
# Processed 342: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-03-01-01-01-15.wav, Emotion: 3
# Processed 343: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-05-01-01-02-15.wav, Emotion: 0
# Processed 344: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-04-01-02-01-15.wav, Emotion: 5
# Processed 345: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-05-01-02-01-15.wav, Emotion: 0
# Processed 346: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-06-02-01-01-15.wav, Emotion: 2
# Processed 347: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-04-01-01-01-15.wav, Emotion: 5
# Processed 348: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-07-01-01-02-15.wav, Emotion: 1
# Processed 349: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-08-02-02-01-15.wav, Emotion: 6
# Processed 350: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-08-01-01-01-15.wav, Emotion: 6
# Processed 351: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-07-01-02-02-15.wav, Emotion: 1
# Processed 352: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-07-02-01-02-15.wav, Emotion: 1
# Processed 353: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-08-01-02-02-15.wav, Emotion: 6
# Processed 354: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-08-02-01-02-15.wav, Emotion: 6
# Processed 355: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-08-02-02-02-15.wav, Emotion: 6
# Processed 356: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-07-02-01-01-15.wav, Emotion: 1
# Processed 357: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-08-02-01-01-15.wav, Emotion: 6
# Processed 358: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-07-02-02-02-15.wav, Emotion: 1
# Processed 359: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-08-01-01-02-15.wav, Emotion: 6
# Processed 360: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-07-02-02-01-15.wav, Emotion: 1
# Processed 361: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-07-01-02-01-15.wav, Emotion: 1
# Processed 362: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-08-01-02-01-15.wav, Emotion: 6
# Processed 363: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-06-02-02-02-15.wav, Emotion: 2
# Processed 364: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_15/03-01-07-01-01-01-15.wav, Emotion: 1
# Processed 365: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-01-01-02-02-11.wav, Emotion: 4
# Processed 366: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-01-01-02-01-11.wav, Emotion: 4
# Processed 367: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-01-01-01-02-11.wav, Emotion: 4
# Processed 368: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-01-01-01-01-11.wav, Emotion: 4
# Processed 369: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-06-02-02-01-11.wav, Emotion: 2
# Processed 370: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-03-02-02-01-11.wav, Emotion: 3
# Processed 371: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-06-01-02-01-11.wav, Emotion: 2
# Processed 372: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-06-01-01-02-11.wav, Emotion: 2
# Processed 373: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-04-02-02-01-11.wav, Emotion: 5
# Processed 374: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-03-01-01-01-11.wav, Emotion: 3
# Processed 375: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-08-02-01-01-11.wav, Emotion: 6
# Processed 376: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-03-02-01-01-11.wav, Emotion: 3
# Processed 377: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-05-01-01-01-11.wav, Emotion: 0
# Processed 378: /content/drive/My Drive/ravdess/archive/audio_speech_actors_01-24/Actor_11/03-01-08-01-02-02-11.wav, Emotion: 6
# ...
# Processed 3992: /content/drive/My Drive/TESS/OAF_Fear/OAF_shout_fear.wav, Emotion: 2
# Processed 3993: /content/drive/My Drive/TESS/OAF_Fear/OAF_pearl_fear.wav, Emotion: 2
# Processed 3994: /content/drive/My Drive/TESS/OAF_Fear/OAF_search_fear.wav, Emotion: 2
# Processed 3995: /content/drive/My Drive/TESS/OAF_Fear/OAF_shack_fear.wav, Emotion: 2
# Processed 3996: /content/drive/My Drive/TESS/OAF_Fear/OAF_shirt_fear.wav, Emotion: 2
# Processed 3997: /content/drive/My Drive/TESS/OAF_Fear/OAF_haze_fear.wav, Emotion: 2
# Processed 3998: /content/drive/My Drive/TESS/OAF_Fear/OAF_hate_fear.wav, Emotion: 2
# Processed 3999: /content/drive/My Drive/TESS/OAF_Fear/OAF_have_fear.wav, Emotion: 2
# Processed 4000: /content/drive/My Drive/TESS/OAF_Fear/OAF_dodge_fear.wav, Emotion: 2
# Processed 4001: /content/drive/My Drive/TESS/OAF_Fear/OAF_mood_fear.wav, Emotion: 2
# Processed 4002: /content/drive/My Drive/TESS/OAF_Fear/OAF_witch_fear.wav, Emotion: 2
# Processed 4003: /content/drive/My Drive/TESS/OAF_Fear/OAF_third_fear.wav, Emotion: 2
# Processed 4004: /content/drive/My Drive/TESS/OAF_Fear/OAF_read_fear.wav, Emotion: 2
# Processed 4005: /content/drive/My Drive/TESS/OAF_Fear/OAF_sub_fear.wav, Emotion: 2
# Processed 4006: /content/drive/My Drive/TESS/OAF_Fear/OAF_wife_fear.wav, Emotion: 2
# Processed 4007: /content/drive/My Drive/TESS/OAF_Fear/OAF_thumb_fear.wav, Emotion: 2
# Processed 4008: /content/drive/My Drive/TESS/OAF_Fear/OAF_luck_fear.wav, Emotion: 2
# Processed 4009: /content/drive/My Drive/TESS/OAF_Fear/OAF_size_fear.wav, Emotion: 2
# Processed 4010: /content/drive/My Drive/TESS/OAF_Fear/OAF_puff_fear.wav, Emotion: 2
# Processed 4011: /content/drive/My Drive/TESS/OAF_Fear/OAF_death_fear.wav, Emotion: 2
# Processed 4012: /content/drive/My Drive/TESS/OAF_Fear/OAF_king_fear.wav, Emotion: 2
# Processed 4013: /content/drive/My Drive/TESS/OAF_Fear/OAF_tell_fear.wav, Emotion: 2
# Processed 4014: /content/drive/My Drive/TESS/OAF_Fear/OAF_which_fear.wav, Emotion: 2
# Processed 4015: /content/drive/My Drive/TESS/OAF_Fear/OAF_hash_fear.wav, Emotion: 2
# Processed 4016: /content/drive/My Drive/TESS/OAF_Fear/OAF_rain_fear.wav, Emotion: 2
# Processed 4017: /content/drive/My Drive/TESS/OAF_Fear/OAF_wheat_fear.wav, Emotion: 2
# Processed 4018: /content/drive/My Drive/TESS/OAF_Fear/OAF_hurl_fear.wav, Emotion: 2
# Processed 4019: /content/drive/My Drive/TESS/OAF_Fear/OAF_pool_fear.wav, Emotion: 2
# Processed 4020: /content/drive/My Drive/TESS/OAF_Fear/OAF_peg_fear.wav, Emotion: 2
# Processed 4021: /content/drive/My Drive/TESS/OAF_Fear/OAF_dab_fear.wav, Emotion: 2
# Processed 4022: /content/drive/My Drive/TESS/OAF_Fear/OAF_gin_fear.wav, Emotion: 2
# Processed 4023: /content/drive/My Drive/TESS/OAF_Fear/OAF_lot_fear.wav, Emotion: 2
# Processed 4024: /content/drive/My Drive/TESS/OAF_Fear/OAF_learn_fear.wav, Emotion: 2
# Processed 4025: /content/drive/My Drive/TESS/OAF_Fear/OAF_lease_fear.wav, Emotion: 2
# Processed 4026: /content/drive/My Drive/TESS/OAF_Fear/OAF_jug_fear.wav, Emotion: 2
# Processed 4027: /content/drive/My Drive/TESS/OAF_Fear/OAF_road_fear.wav, Emotion: 2
# Processed 4028: /content/drive/My Drive/TESS/OAF_Fear/OAF_moon_fear.wav, Emotion: 2
# Processed 4029: /content/drive/My Drive/TESS/OAF_Fear/OAF_ring_fear.wav, Emotion: 2
# Processed 4030: /content/drive/My Drive/TESS/OAF_Fear/OAF_wash_fear.wav, Emotion: 2
# Processed 4031: /content/drive/My Drive/TESS/OAF_Fear/OAF_south_fear.wav, Emotion: 2
# Processed 4032: /content/drive/My Drive/TESS/OAF_Fear/OAF_good_fear.wav, Emotion: 2
# Processed 4033: /content/drive/My Drive/TESS/OAF_Fear/OAF_kick_fear.wav, Emotion: 2
# Processed 4034: /content/drive/My Drive/TESS/OAF_Fear/OAF_hush_fear.wav, Emotion: 2
# Processed 4035: /content/drive/My Drive/TESS/OAF_Fear/OAF_soup_fear.wav, Emotion: 2
# Processed 4036: /content/drive/My Drive/TESS/OAF_Fear/OAF_mess_fear.wav, Emotion: 2
# Processed 4037: /content/drive/My Drive/TESS/OAF_Fear/OAF_when_fear.wav, Emotion: 2
# Processed 4038: /content/drive/My Drive/TESS/OAF_Fear/OAF_time_fear.wav, Emotion: 2
# Processed 4039: /content/drive/My Drive/TESS/OAF_Fear/OAF_match_fear.wav, Emotion: 2
# Processed 4040: /content/drive/My Drive/TESS/OAF_Fear/OAF_room_fear.wav, Emotion: 2
# Processed 4041: /content/drive/My Drive/TESS/OAF_Fear/OAF_join_fear.wav, Emotion: 2
# Processed 4042: /content/drive/My Drive/TESS/OAF_Fear/OAF_young_fear.wav, Emotion: 2
# Processed 4043: /content/drive/My Drive/TESS/OAF_Fear/OAF_void_fear.wav, Emotion: 2
# Processed 4044: /content/drive/My Drive/TESS/OAF_Fear/OAF_pain_fear.wav, Emotion: 2
# Processed 4045: /content/drive/My Drive/TESS/OAF_Fear/OAF_red_fear.wav, Emotion: 2
# Processed 4046: /content/drive/My Drive/TESS/OAF_Fear/OAF_rose_fear.wav, Emotion: 2
# Processed 4047: /content/drive/My Drive/TESS/OAF_Fear/OAF_voice_fear.wav, Emotion: 2
# Processed 4048: /content/drive/My Drive/TESS/OAF_Fear/OAF_lid_fear.wav, Emotion: 2
# Processed 4049: /content/drive/My Drive/TESS/OAF_Fear/OAF_late_fear.wav, Emotion: 2
# Processed 4050: /content/drive/My Drive/TESS/OAF_Fear/OAF_date_fear.wav, Emotion: 2
# Processed 4051: /content/drive/My Drive/TESS/OAF_Fear/OAF_take_fear.wav, Emotion: 2
# Processed 4052: /content/drive/My Drive/TESS/OAF_Fear/OAF_soap_fear.wav, Emotion: 2
# Processed 4053: /content/drive/My Drive/TESS/OAF_Fear/OAF_said_fear.wav, Emotion: 2
# Processed 4054: /content/drive/My Drive/TESS/OAF_Fear/OAF_live_fear.wav, Emotion: 2
# Processed 4055: /content/drive/My Drive/savee/DC_a01.wav, Emotion: 0
# Processed 4056: /content/drive/My Drive/savee/DC_a04.wav, Emotion: 0
# Processed 4057: /content/drive/My Drive/savee/DC_a14.wav, Emotion: 0
# Processed 4058: /content/drive/My Drive/savee/DC_a13.wav, Emotion: 0
# Processed 4059: /content/drive/My Drive/savee/DC_a10.wav, Emotion: 0
# Processed 4060: /content/drive/My Drive/savee/DC_a02.wav, Emotion: 0
# Processed 4061: /content/drive/My Drive/savee/DC_a07.wav, Emotion: 0
# Processed 4062: /content/drive/My Drive/savee/DC_a05.wav, Emotion: 0
# Processed 4063: /content/drive/My Drive/savee/DC_a09.wav, Emotion: 0
# Processed 4064: /content/drive/My Drive/savee/DC_a06.wav, Emotion: 0
# Processed 4065: /content/drive/My Drive/savee/DC_a08.wav, Emotion: 0
# Processed 4066: /content/drive/My Drive/savee/DC_a12.wav, Emotion: 0
# Processed 4067: /content/drive/My Drive/savee/DC_a03.wav, Emotion: 0
# Processed 4068: /content/drive/My Drive/savee/DC_a11.wav, Emotion: 0
# Processed 4069: /content/drive/My Drive/savee/DC_f14.wav, Emotion: 2
# Processed 4070: /content/drive/My Drive/savee/DC_f02.wav, Emotion: 2
# Processed 4071: /content/drive/My Drive/savee/DC_d06.wav, Emotion: 1
# Processed 4072: /content/drive/My Drive/savee/DC_h12.wav, Emotion: 3
# Processed 4073: /content/drive/My Drive/savee/DC_d02.wav, Emotion: 1
# Processed 4074: /content/drive/My Drive/savee/DC_d03.wav, Emotion: 1
# Processed 4075: /content/drive/My Drive/savee/DC_h08.wav, Emotion: 3
# Processed 4076: /content/drive/My Drive/savee/DC_h10.wav, Emotion: 3
# Processed 4077: /content/drive/My Drive/savee/DC_f07.wav, Emotion: 2
# Processed 4078: /content/drive/My Drive/savee/DC_d09.wav, Emotion: 1
# Processed 4079: /content/drive/My Drive/savee/DC_h13.wav, Emotion: 3
# Processed 4080: /content/drive/My Drive/savee/DC_f04.wav, Emotion: 2
# Processed 4081: /content/drive/My Drive/savee/DC_d11.wav, Emotion: 1
# Processed 4082: /content/drive/My Drive/savee/DC_d04.wav, Emotion: 1
# Processed 4083: /content/drive/My Drive/savee/DC_f13.wav, Emotion: 2
# Processed 4084: /content/drive/My Drive/savee/DC_h09.wav, Emotion: 3
# Processed 4085: /content/drive/My Drive/savee/DC_d10.wav, Emotion: 1
# Processed 4086: /content/drive/My Drive/savee/DC_h14.wav, Emotion: 3
# Processed 4087: /content/drive/My Drive/savee/DC_h15.wav, Emotion: 3
# Processed 4088: /content/drive/My Drive/savee/DC_h03.wav, Emotion: 3
# Processed 4089: /content/drive/My Drive/savee/DC_f03.wav, Emotion: 2
# Processed 4090: /content/drive/My Drive/savee/DC_n01.wav, Emotion: 4
# Processed 4091: /content/drive/My Drive/savee/DC_d14.wav, Emotion: 1
# Processed 4092: /content/drive/My Drive/savee/DC_h07.wav, Emotion: 3
# Processed 4093: /content/drive/My Drive/savee/DC_d13.wav, Emotion: 1
# Processed 4094: /content/drive/My Drive/savee/DC_h02.wav, Emotion: 3
# Processed 4095: /content/drive/My Drive/savee/DC_f12.wav, Emotion: 2
# Processed 4096: /content/drive/My Drive/savee/DC_d12.wav, Emotion: 1
# Processed 4097: /content/drive/My Drive/savee/DC_h01.wav, Emotion: 3
# Processed 4098: /content/drive/My Drive/savee/DC_d15.wav, Emotion: 1
# Processed 4099: /content/drive/My Drive/savee/DC_d08.wav, Emotion: 1
# Processed 4100: /content/drive/My Drive/savee/DC_d01.wav, Emotion: 1
# Processed 4101: /content/drive/My Drive/savee/DC_a15.wav, Emotion: 0
# Processed 4102: /content/drive/My Drive/savee/DC_n02.wav, Emotion: 4
# Processed 4103: /content/drive/My Drive/savee/DC_f05.wav, Emotion: 2
# Processed 4104: /content/drive/My Drive/savee/DC_f15.wav, Emotion: 2
# Processed 4105: /content/drive/My Drive/savee/DC_h06.wav, Emotion: 3
# Processed 4106: /content/drive/My Drive/savee/DC_h04.wav, Emotion: 3
# Processed 4107: /content/drive/My Drive/savee/DC_f01.wav, Emotion: 2
# Processed 4108: /content/drive/My Drive/savee/DC_f10.wav, Emotion: 2
# Processed 4109: /content/drive/My Drive/savee/DC_f09.wav, Emotion: 2
# Processed 4110: /content/drive/My Drive/savee/DC_d07.wav, Emotion: 1
# Processed 4111: /content/drive/My Drive/savee/DC_n03.wav, Emotion: 4
# Processed 4112: /content/drive/My Drive/savee/DC_h11.wav, Emotion: 3
# Processed 4113: /content/drive/My Drive/savee/DC_d05.wav, Emotion: 1
# Processed 4114: /content/drive/My Drive/savee/DC_f11.wav, Emotion: 2
# Processed 4115: /content/drive/My Drive/savee/DC_h05.wav, Emotion: 3
# Processed 4116: /content/drive/My Drive/savee/DC_f06.wav, Emotion: 2
# Processed 4117: /content/drive/My Drive/savee/DC_f08.wav, Emotion: 2
# Processed 4118: /content/drive/My Drive/savee/DC_su08.wav, Emotion: 6
# Processed 4119: /content/drive/My Drive/savee/DC_su05.wav, Emotion: 6
# Processed 4120: /content/drive/My Drive/savee/DC_su03.wav, Emotion: 6
# Processed 4121: /content/drive/My Drive/savee/DC_n04.wav, Emotion: 4
# Processed 4122: /content/drive/My Drive/savee/DC_n20.wav, Emotion: 4
# Processed 4123: /content/drive/My Drive/savee/DC_sa12.wav, Emotion: 5
# Processed 4124: /content/drive/My Drive/savee/DC_n07.wav, Emotion: 4
# Processed 4125: /content/drive/My Drive/savee/DC_n18.wav, Emotion: 4
# Processed 4126: /content/drive/My Drive/savee/DC_n26.wav, Emotion: 4
# Processed 4127: /content/drive/My Drive/savee/DC_n14.wav, Emotion: 4
# Processed 4128: /content/drive/My Drive/savee/DC_su04.wav, Emotion: 6
# Processed 4129: /content/drive/My Drive/savee/DC_sa08.wav, Emotion: 5
# Processed 4130: /content/drive/My Drive/savee/DC_n19.wav, Emotion: 4
# Processed 4131: /content/drive/My Drive/savee/DC_sa09.wav, Emotion: 5
# Processed 4132: /content/drive/My Drive/savee/DC_sa14.wav, Emotion: 5
# Processed 4133: /content/drive/My Drive/savee/DC_sa07.wav, Emotion: 5
# Processed 4134: /content/drive/My Drive/savee/DC_n30.wav, Emotion: 4
# Processed 4135: /content/drive/My Drive/savee/DC_n15.wav, Emotion: 4
# Processed 4136: /content/drive/My Drive/savee/DC_su02.wav, Emotion: 6
# Processed 4137: /content/drive/My Drive/savee/DC_sa06.wav, Emotion: 5
# Processed 4138: /content/drive/My Drive/savee/DC_sa01.wav, Emotion: 5
# Processed 4139: /content/drive/My Drive/savee/DC_n25.wav, Emotion: 4
# Processed 4140: /content/drive/My Drive/savee/DC_n08.wav, Emotion: 4
# Processed 4141: /content/drive/My Drive/savee/DC_su07.wav, Emotion: 6
# Processed 4142: /content/drive/My Drive/savee/DC_sa15.wav, Emotion: 5
# Processed 4143: /content/drive/My Drive/savee/DC_sa03.wav, Emotion: 5
# Processed 4144: /content/drive/My Drive/savee/DC_n24.wav, Emotion: 4
# Processed 4145: /content/drive/My Drive/savee/DC_n22.wav, Emotion: 4
# Processed 4146: /content/drive/My Drive/savee/DC_sa05.wav, Emotion: 5
# Processed 4147: /content/drive/My Drive/savee/DC_su01.wav, Emotion: 6
# Processed 4148: /content/drive/My Drive/savee/DC_sa13.wav, Emotion: 5
# Processed 4149: /content/drive/My Drive/savee/DC_sa10.wav, Emotion: 5
# Processed 4150: /content/drive/My Drive/savee/DC_n27.wav, Emotion: 4
# Processed 4151: /content/drive/My Drive/savee/DC_sa11.wav, Emotion: 5
# Processed 4152: /content/drive/My Drive/savee/DC_n06.wav, Emotion: 4
# Processed 4153: /content/drive/My Drive/savee/DC_n23.wav, Emotion: 4
# Processed 4154: /content/drive/My Drive/savee/DC_n17.wav, Emotion: 4
# Processed 4155: /content/drive/My Drive/savee/DC_n10.wav, Emotion: 4
# Processed 4156: /content/drive/My Drive/savee/DC_n21.wav, Emotion: 4
# Processed 4157: /content/drive/My Drive/savee/DC_sa02.wav, Emotion: 5
# Processed 4158: /content/drive/My Drive/savee/DC_su06.wav, Emotion: 6
# Processed 4159: /content/drive/My Drive/savee/DC_su09.wav, Emotion: 6
# Processed 4160: /content/drive/My Drive/savee/DC_n09.wav, Emotion: 4
# Processed 4161: /content/drive/My Drive/savee/DC_n16.wav, Emotion: 4
# Processed 4162: /content/drive/My Drive/savee/DC_n13.wav, Emotion: 4
# Processed 4163: /content/drive/My Drive/savee/DC_n12.wav, Emotion: 4
# Processed 4164: /content/drive/My Drive/savee/DC_sa04.wav, Emotion: 5
# Processed 4165: /content/drive/My Drive/savee/DC_n11.wav, Emotion: 4
# Processed 4166: /content/drive/My Drive/savee/DC_n28.wav, Emotion: 4
# Processed 4167: /content/drive/My Drive/savee/DC_n29.wav, Emotion: 4
# Processed 4168: /content/drive/My Drive/savee/DC_n05.wav, Emotion: 4
# Processed 4169: /content/drive/My Drive/savee/DC_su14.wav, Emotion: 6
# Processed 4170: /content/drive/My Drive/savee/JE_f03.wav, Emotion: 2
# Processed 4171: /content/drive/My Drive/savee/JE_d01.wav, Emotion: 1
# Processed 4172: /content/drive/My Drive/savee/DC_su11.wav, Emotion: 6
# Processed 4173: /content/drive/My Drive/savee/JE_d09.wav, Emotion: 1
# Processed 4174: /content/drive/My Drive/savee/JE_d08.wav, Emotion: 1
# Processed 4175: /content/drive/My Drive/savee/JE_d13.wav, Emotion: 1
# Processed 4176: /content/drive/My Drive/savee/JE_d06.wav, Emotion: 1
# Processed 4177: /content/drive/My Drive/savee/JE_a15.wav, Emotion: 0
# Processed 4178: /content/drive/My Drive/savee/DC_su13.wav, Emotion: 6
# Processed 4179: /content/drive/My Drive/savee/JE_d14.wav, Emotion: 1
# Processed 4180: /content/drive/My Drive/savee/JE_a04.wav, Emotion: 0
# Processed 4181: /content/drive/My Drive/savee/DC_su12.wav, Emotion: 6
# Processed 4182: /content/drive/My Drive/savee/JE_d02.wav, Emotion: 1
# Processed 4183: /content/drive/My Drive/savee/DC_su15.wav, Emotion: 6
# Processed 4184: /content/drive/My Drive/savee/JE_a11.wav, Emotion: 0
# Processed 4185: /content/drive/My Drive/savee/JE_f02.wav, Emotion: 2
# Processed 4186: /content/drive/My Drive/savee/JE_a10.wav, Emotion: 0
# Processed 4187: /content/drive/My Drive/savee/JE_a02.wav, Emotion: 0
# Processed 4188: /content/drive/My Drive/savee/JE_d15.wav, Emotion: 1
# Processed 4189: /content/drive/My Drive/savee/JE_d11.wav, Emotion: 1
# Processed 4190: /content/drive/My Drive/savee/JE_a03.wav, Emotion: 0
# Processed 4191: /content/drive/My Drive/savee/JE_a01.wav, Emotion: 0
# Processed 4192: /content/drive/My Drive/savee/DC_su10.wav, Emotion: 6
# Processed 4193: /content/drive/My Drive/savee/JE_a07.wav, Emotion: 0
# Processed 4194: /content/drive/My Drive/savee/JE_f01.wav, Emotion: 2
# Processed 4195: /content/drive/My Drive/savee/JE_a13.wav, Emotion: 0
# Processed 4196: /content/drive/My Drive/savee/JE_a14.wav, Emotion: 0
# Processed 4197: /content/drive/My Drive/savee/JE_d04.wav, Emotion: 1
# Processed 4198: /content/drive/My Drive/savee/JE_d05.wav, Emotion: 1
# Processed 4199: /content/drive/My Drive/savee/JE_d12.wav, Emotion: 1
# Processed 4200: /content/drive/My Drive/savee/JE_a06.wav, Emotion: 0
# Processed 4201: /content/drive/My Drive/savee/JE_d07.wav, Emotion: 1
# Processed 4202: /content/drive/My Drive/savee/JE_a09.wav, Emotion: 0
# Processed 4203: /content/drive/My Drive/savee/JE_a08.wav, Emotion: 0
# Processed 4204: /content/drive/My Drive/savee/JE_a05.wav, Emotion: 0
# Processed 4205: /content/drive/My Drive/savee/JE_d03.wav, Emotion: 1
# Processed 4206: /content/drive/My Drive/savee/JE_a12.wav, Emotion: 0
# Processed 4207: /content/drive/My Drive/savee/JE_d10.wav, Emotion: 1
# Number of processed audio files: 4207
# Number of labels: 4207

# %%
# Divide the data into training and testing sets, with a 80:20 split
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_mfcc, y_mfcc,
                                                    test_size=0.2,
                                                    random_state=0,
                                                    shuffle=True)

# Check the length of the training and testing sets
print('Number of training images:', len(X_train_2))
print('Number of testing images:', len(X_test_2))
print('Number of training labels:', len(y_train_2))
print('Number of testing labels:', len(y_test_2))
# Out:
# Number of training images: 3365
# Number of testing images: 842
# Number of training labels: 3365
# Number of testing labels: 842

# %%
# Convert the lists into numpy arrays
X_train_2 = np.array(X_train_2)
X_test_2 = np.array(X_test_2)
y_train_2 = np.array(y_train_2)
y_test_2 = np.array(y_test_2)
# Check the shape of the arrays
print('X_train shape:', X_train_2.shape)
print('X_test shape:', X_test_2.shape)
print('y_train shape:', y_train_2.shape)
print('y_test shape:', y_test_2.shape)
# Out:
# X_train shape: (3365, 128, 345)
# X_test shape: (842, 128, 345)
# y_train shape: (3365,)
# y_test shape: (842,)

# %%
# Standardize the data by subtracting the mean and dividing by the standard deviation
mean = np.mean(X_train_2)
std = np.std(X_train_2)
X_train_2 = (X_train_2 - mean) / std
X_test_2 = (X_test_2 - mean) / std

# %%
# Check the mean and standard deviation
print('Mean:', mean)
print('Standard deviation:', std)
# Check if the data is standardized
print('Mean of standardized data:', np.mean(X_train_2))
print('Standard deviation of standardized data:', np.std(X_train_2))
# Out:
# Mean: -3.9084709
# Standard deviation: 54.149414
# Mean of standardized data: 1.4520774e-07
# Standard deviation of standardized data: 1.000004

# %%
# Reshape the data into 4D arrays so that it can be input into the 2D CNN
X_train_2 = X_train_2.reshape(X_train_2.shape[0], 128, 345, 1)
X_test_2 = X_test_2.reshape(X_test_2.shape[0], 128, 345, 1)
# Check the shape of the arrays
print('X_train shape:', X_train_2.shape)
print('X_test shape:', X_test_2.shape)
# Out:
# X_train shape: (3365, 128, 345, 1)
# X_test shape: (842, 128, 345, 1)

# %%
# Divide the data into batches of 32 images
batch_size = 32
# Make a training dataset from the training set
train_dataset_2 = tf.data.Dataset.from_tensor_slices((X_train_2, y_train_2))
# Shuffle, batch, and prefetch the data
train_dataset_2 = train_dataset_2.batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
# Make a testing dataset from the testing set
test_dataset_2 = tf.data.Dataset.from_tensor_slices((X_test_2, y_test_2))
# Shuffle, batch, and prefetch the data
test_dataset_2 = test_dataset_2.batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
# Define the CNN model
model_mfcc = tf.keras.Sequential([
    # First convolutional layer
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 345, 1), padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    # Batch normalization maintains the 0 mean and 1 standard deviation
    tf.keras.layers.BatchNormalization(),
    # Second convolutional layer
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.BatchNormalization(),
    # Third convolutional layer
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.BatchNormalization(),
    # Fourth convolutional layer
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.BatchNormalization(),
    # Global average pooling layer averages the values in each feature map into
    # a single value and flattens the result into a (none, 256) array
    tf.keras.layers.GlobalAveragePooling2D(),
    # Dropout layer randomly sets 50% of the activations to zero
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(7, activation='softmax')
])

# %%
# Compile the model
model_mfcc.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Plot the model architecture
tf.keras.utils.plot_model(model_mfcc, show_shapes=True, to_file='model_mfcc.png')

# %%
# # Create a callback that stops training when the validation loss plateaus or increases
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, mode = 'min')

# Create a callback that adjusts the learning rate gradually
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                    factor=0.2,
                                                    min_lr=0.000001,
                                                    patience=3,
                                                    mode='min')




# Initialize a deque to store the last 1000 iterations of weights
weights_history = deque(maxlen=1000)

# Custom callback to save weights during training
class SaveWeightsCallback(tf.keras.callbacks.Callback):
    def on_train_batch_end(self, batch, logs=None):
        # Save the model's current weights at the end of each batch
        weights = self.model.get_weights()  # Get model weights
        flattened_weights = np.concatenate([w.flatten() for w in weights])  # Flatten and concatenate
        weights_history.append(flattened_weights)  # Append to deque

# Initialize the callback
save_weights_callback = SaveWeightsCallback()

# fit the model
history_mfcc = model_mfcc.fit(train_dataset_2,
                    epochs=40,
                    validation_data=test_dataset_2,
                    callbacks=[early_stop, lr_scheduler,save_weights_callback])


# Convert deque to a NumPy array after training
weights_history_np = np.array(weights_history)

# Inspect the shape of the saved weights
print("Shape of weights history:", weights_history_np.shape)

# Optionally save weights history to a file
np.save("weights_history.npy", weights_history_np)

#############################################################################################3333
# Specify the path to save the file in Google Drive
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/drive')
save_path = '/content/drive/My Drive/weights_history_mfcc.npy'

# Save the weights_history_np array
np.save(save_path, weights_history_np)

print(f"Weights history saved to: {save_path}")
# Out:
# Epoch 1/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 487s 5s/step - accuracy: 0.5386 - loss: 1.3830 - val_accuracy: 0.1401 - val_loss: 3.7892 - learning_rate: 0.0010
# Epoch 2/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 486s 4s/step - accuracy: 0.7494 - loss: 0.7838 - val_accuracy: 0.1556 - val_loss: 4.3834 - learning_rate: 0.0010
# Epoch 3/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 466s 4s/step - accuracy: 0.8190 - loss: 0.6036 - val_accuracy: 0.2767 - val_loss: 5.5754 - learning_rate: 0.0010
# Epoch 4/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 460s 4s/step - accuracy: 0.8423 - loss: 0.4972 - val_accuracy: 0.2696 - val_loss: 4.5806 - learning_rate: 0.0010
# Epoch 5/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 463s 4s/step - accuracy: 0.8831 - loss: 0.3937 - val_accuracy: 0.2280 - val_loss: 3.4829 - learning_rate: 2.0000e-04
# Epoch 6/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 496s 4s/step - accuracy: 0.9035 - loss: 0.3294 - val_accuracy: 0.5238 - val_loss: 1.8103 - learning_rate: 2.0000e-04
# Epoch 7/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 459s 4s/step - accuracy: 0.9063 - loss: 0.2980 - val_accuracy: 0.7114 - val_loss: 0.9075 - learning_rate: 2.0000e-04
# Epoch 8/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 457s 4s/step - accuracy: 0.9117 - loss: 0.2743 - val_accuracy: 0.7506 - val_loss: 0.7723 - learning_rate: 2.0000e-04
# Epoch 9/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 501s 4s/step - accuracy: 0.9294 - loss: 0.2469 - val_accuracy: 0.7352 - val_loss: 0.8607 - learning_rate: 2.0000e-04
# Epoch 10/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 500s 4s/step - accuracy: 0.9347 - loss: 0.2261 - val_accuracy: 0.7458 - val_loss: 0.8600 - learning_rate: 2.0000e-04
# Epoch 11/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 505s 4s/step - accuracy: 0.9463 - loss: 0.2020 - val_accuracy: 0.7648 - val_loss: 0.7659 - learning_rate: 2.0000e-04
# Epoch 12/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 502s 4s/step - accuracy: 0.9512 - loss: 0.1804 - val_accuracy: 0.8147 - val_loss: 0.5658 - learning_rate: 2.0000e-04
# Epoch 13/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 461s 4s/step - accuracy: 0.9623 - loss: 0.1471 - val_accuracy: 0.8135 - val_loss: 0.6112 - learning_rate: 2.0000e-04
# Epoch 14/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 497s 4s/step - accuracy: 0.9700 - loss: 0.1335 - val_accuracy: 0.8195 - val_loss: 0.5999 - learning_rate: 2.0000e-04
# Epoch 15/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 457s 4s/step - accuracy: 0.9809 - loss: 0.1125 - val_accuracy: 0.7102 - val_loss: 0.9803 - learning_rate: 2.0000e-04
# Epoch 16/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 450s 4s/step - accuracy: 0.9855 - loss: 0.0937 - val_accuracy: 0.9086 - val_loss: 0.2629 - learning_rate: 4.0000e-05
# Epoch 17/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 522s 4s/step - accuracy: 0.9908 - loss: 0.0876 - val_accuracy: 0.9145 - val_loss: 0.2539 - learning_rate: 4.0000e-05
# Epoch 18/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 454s 4s/step - accuracy: 0.9945 - loss: 0.0752 - val_accuracy: 0.9109 - val_loss: 0.2467 - learning_rate: 4.0000e-05
# Epoch 19/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 453s 4s/step - accuracy: 0.9940 - loss: 0.0749 - val_accuracy: 0.9074 - val_loss: 0.2547 - learning_rate: 4.0000e-05
# Epoch 20/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 503s 4s/step - accuracy: 0.9970 - loss: 0.0707 - val_accuracy: 0.9145 - val_loss: 0.2469 - learning_rate: 4.0000e-05
# Epoch 21/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 455s 4s/step - accuracy: 0.9955 - loss: 0.0686 - val_accuracy: 0.9074 - val_loss: 0.2489 - learning_rate: 4.0000e-05
# Epoch 22/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 453s 4s/step - accuracy: 0.9971 - loss: 0.0634 - val_accuracy: 0.9169 - val_loss: 0.2273 - learning_rate: 8.0000e-06
# Epoch 23/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 453s 4s/step - accuracy: 0.9981 - loss: 0.0616 - val_accuracy: 0.9181 - val_loss: 0.2257 - learning_rate: 8.0000e-06
# Epoch 24/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 503s 4s/step - accuracy: 0.9957 - loss: 0.0611 - val_accuracy: 0.9192 - val_loss: 0.2256 - learning_rate: 8.0000e-06
# Epoch 25/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 455s 4s/step - accuracy: 0.9951 - loss: 0.0612 - val_accuracy: 0.9192 - val_loss: 0.2222 - learning_rate: 8.0000e-06
# Epoch 26/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 457s 4s/step - accuracy: 0.9973 - loss: 0.0576 - val_accuracy: 0.9192 - val_loss: 0.2208 - learning_rate: 8.0000e-06
# Epoch 27/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 497s 4s/step - accuracy: 0.9975 - loss: 0.0615 - val_accuracy: 0.9145 - val_loss: 0.2238 - learning_rate: 8.0000e-06
# Epoch 28/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 506s 4s/step - accuracy: 0.9970 - loss: 0.0593 - val_accuracy: 0.9204 - val_loss: 0.2242 - learning_rate: 8.0000e-06
# Epoch 29/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 501s 4s/step - accuracy: 0.9972 - loss: 0.0576 - val_accuracy: 0.9181 - val_loss: 0.2241 - learning_rate: 8.0000e-06
# Epoch 30/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 455s 4s/step - accuracy: 0.9975 - loss: 0.0562 - val_accuracy: 0.9169 - val_loss: 0.2209 - learning_rate: 1.6000e-06
# Epoch 31/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 452s 4s/step - accuracy: 0.9982 - loss: 0.0557 - val_accuracy: 0.9181 - val_loss: 0.2207 - learning_rate: 1.6000e-06
# Epoch 32/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 453s 4s/step - accuracy: 0.9992 - loss: 0.0570 - val_accuracy: 0.9181 - val_loss: 0.2209 - learning_rate: 1.6000e-06
# Epoch 33/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 465s 4s/step - accuracy: 0.9971 - loss: 0.0575 - val_accuracy: 0.9169 - val_loss: 0.2210 - learning_rate: 1.0000e-06
# Epoch 34/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 450s 4s/step - accuracy: 0.9967 - loss: 0.0556 - val_accuracy: 0.9169 - val_loss: 0.2211 - learning_rate: 1.0000e-06
# Epoch 35/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 506s 4s/step - accuracy: 0.9980 - loss: 0.0554 - val_accuracy: 0.9169 - val_loss: 0.2213 - learning_rate: 1.0000e-06
# Epoch 36/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 500s 4s/step - accuracy: 0.9967 - loss: 0.0567 - val_accuracy: 0.9169 - val_loss: 0.2213 - learning_rate: 1.0000e-06
# Epoch 37/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 453s 4s/step - accuracy: 0.9968 - loss: 0.0570 - val_accuracy: 0.9169 - val_loss: 0.2212 - learning_rate: 1.0000e-06
# Epoch 38/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 512s 4s/step - accuracy: 0.9975 - loss: 0.0555 - val_accuracy: 0.9157 - val_loss: 0.2215 - learning_rate: 1.0000e-06
# Epoch 39/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 448s 4s/step - accuracy: 0.9984 - loss: 0.0569 - val_accuracy: 0.9157 - val_loss: 0.2215 - learning_rate: 1.0000e-06
# Epoch 40/40
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 446s 4s/step - accuracy: 0.9975 - loss: 0.0545 - val_accuracy: 0.9157 - val_loss: 0.2214 - learning_rate: 1.0000e-06
# Shape of weights history: (1000, 391559)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Weights history saved to: /content/drive/My Drive/weights_history_mfcc.npy

# %%
# Plot the training and validation accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history_mfcc.history['accuracy'], label='Training')
plt.plot(history_mfcc.history['val_accuracy'], label='Validation')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.legend()
# Plot the training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history_mfcc.history['loss'], label='Training')
plt.plot(history_mfcc.history['val_loss'], label='Validation')
plt.title('Loss')
plt.xlabel('Epoch')
plt.legend()

# %%
def sample_W(W, nSamples, isRandom=True):
    n = W.shape[0]
    random_indices = np.random.choice(n, size=nSamples, replace=False)
    return W[random_indices]


def calculate_ph_dim(
    W, min_points=200, max_points=1000, point_jump=50, h_dim=0, print_error=False
):
    from ripser import ripser

    # sample_fn should output a [num_points, dim] array

    # sample our points
    test_n = range(min_points, max_points, point_jump)
    lengths = []
    for n in test_n:
        diagrams = ripser(sample_W(W, n))[
            "dgms"
        ]  # list of persistance diagram for differnt homology dimension

        if len(diagrams) > h_dim:
            d = diagrams[h_dim]
            d = d[d[:, 1] < np.inf]
            lengths.append((d[:, 1] - d[:, 0]).sum())
        else:
            lengths.append(0.0)
    lengths = np.array(lengths)
    # compute our ph dim by running a linear least squares
    x = np.log(np.array(list(test_n)))
    y = np.log(lengths)
    N = len(x)
    m = (N * (x * y).sum() - x.sum() * y.sum()) / (N * (x**2).sum() - x.sum() ** 2)
    b = y.mean() - m * x.mean()

    error = ((y - (m * x + b)) ** 2).mean()

    if print_error:
        print(f"Ph Dimension Calculation has an approximate error of: {error}.")
    return 1 / (1 - m)
# Out:
# Collecting ripser
#   Downloading ripser-0.6.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from ripser) (3.0.11)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ripser) (1.26.4)
# Collecting persim (from ripser)
#   Downloading persim-0.3.7-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ripser) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from ripser) (1.6.0)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.10/dist-packages (from persim->ripser) (1.2.15)
# Collecting hopcroftkarp (from persim->ripser)
#   Downloading hopcroftkarp-1.2.5.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from persim->ripser) (1.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from persim->ripser) (3.8.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ripser) (3.5.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->persim->ripser) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->persim->ripser) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->persim->ripser) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->persim->ripser) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->persim->ripser) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->persim->ripser) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->persim->ripser) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->persim->ripser) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->persim->ripser) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->persim->ripser) (1.17.0)
# Downloading ripser-0.6.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (834 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 834.5/834.5 kB 27.9 MB/s eta 0:00:00
# Downloading persim-0.3.7-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 2.7 MB/s eta 0:00:00
# Building wheels for collected packages: hopcroftkarp
#   Building wheel for hopcroftkarp (setup.py) ... done
#   Created wheel for hopcroftkarp: filename=hopcroftkarp-1.2.5-py2.py3-none-any.whl size=18102 sha256=a5350cfef68e7028a4325885d905d738dd36d167e6711c826f5cfcc3edd34939
#   Stored in directory: /root/.cache/pip/wheels/ef/0f/3b/0f931844eecc34addd90e72d54cd39c08b7066c5f25c00b9a4
# Successfully built hopcroftkarp
# Installing collected packages: hopcroftkarp, persim, ripser
# Successfully installed hopcroftkarp-1.2.5 persim-0.3.7 ripser-0.6.10

# %%
import ripser
ph_dim = calculate_ph_dim(weights_history_np)
print(f" the approximated PH dimension is {ph_dim}")

# Specify the path where you want to save the file
save_ph_path = '/content/drive/My Drive/phd_dimension_mfcc.txt'

# Save the `ph_dim` value to the text file
with open(save_ph_path, 'w') as f:
    f.write(f"The approximated PH dimension  for MFCC CNN is {ph_dim}\n")

print(f"PH dimension saved to: {save_ph_path}")
# Out:
#  the approximated PH dimension is 3.588839854649933
# PH dimension saved to: /content/drive/My Drive/phd_dimension_mfcc.txt

# %%
# Measure the precision and recall
y_pred = model_mfcc.predict(X_test_2)
# Convert the predictions into one-hot encoded vectors
y_pred = np.argmax(y_pred, axis=1)
# Plot the classification report
print(classification_report(y_test_2, y_pred, target_names=encoder.classes_))
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step
#               precision    recall  f1-score   support
#
#        anger       0.93      0.94      0.94       131
#      disgust       0.89      0.92      0.90       119
#         fear       0.89      0.92      0.91       118
#    happiness       0.92      0.87      0.89       117
#      neutral       0.95      0.94      0.94       109
#      sadness       0.91      0.89      0.90       128
#     surprise       0.93      0.95      0.94       120
#
#     accuracy                           0.92       842
#    macro avg       0.92      0.92      0.92       842
# weighted avg       0.92      0.92      0.92       842

# %%
# Plot the confusion matrix for the validation set
# Get the predictions for the test data
y_pred = model_mfcc.predict(X_test_2)
# Convert the predictions into one-hot encoded vectors
y_pred = np.argmax(y_pred, axis=1)
# Get the confusion matrix
cm = tf.math.confusion_matrix(y_test_2, y_pred)
# Plot the confusion matrix
plt.figure(figsize=(10, 8))
# Make the index and column labels the emotion names
cm = pd.DataFrame(cm.numpy(), index=encoder.classes_, columns=encoder.classes_)
sns.heatmap(cm, annot=True, fmt='', cmap='mako')
plt.title('MFCC Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout(pad=2)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step
